# %%
import anndata as ad
from cellbender.remove_background.downstream import load_anndata_from_input_and_output

adata = load_anndata_from_input_and_output(
    input_file='/home/sofia/Projects/etmr/defaria/scRNA/jessa/data/raw/raw_feature_bc_matrix.h5',
    output_file='/home/sofia/Projects/etmr/defaria/scRNA/jessa/data/processed/jessa_background.h5',
    input_layer_key='raw',
    retain_input_metadata=True)
adata

adata.write_h5ad("/home/sofia/Projects/etmr/defaria/scRNA/jessa/data/processed/jessa_all.h5ad")
